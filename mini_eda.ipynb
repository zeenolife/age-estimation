# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
age_imdb = []
for i in range(120):
    num_files = len(os.listdir('data/processed/imdb/train/' + str(i)))
    age_imdb += [i] * num_files

# %%
plt.figure(figsize=(20,20))
sns.countplot(age_imdb)

# %%
age_utk = []
for i in range(120):
    num_files = len(os.listdir('data/processed/utk/train/' + str(i)))
    age_utk += [i] * num_files

plt.figure(figsize=(20,20))
sns.countplot(age_utk)

# %%
age_utk = []
for i in range(120):
    num_files = len(os.listdir('data/processed/appa-real/train/' + str(i)))
    age_utk += [i] * num_files

plt.figure(figsize=(20,20))
sns.countplot(age_utk)

# %%
age_utk = []
for i in range(120):
    num_files = len(os.listdir('data/processed/sof/test/' + str(i)))
    age_utk += [i] * num_files

plt.figure(figsize=(20,20))
sns.countplot(age_utk)
